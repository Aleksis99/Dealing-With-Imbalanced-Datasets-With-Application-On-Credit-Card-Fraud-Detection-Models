# %% [markdown]
# # Dealing With Imbalanced Datasets And Lack Of Domain Knowledge With Application On Credit Card Fraud Detection Models

# %% [markdown]
#  # Overview
#
# Abstract
#
# Data Acquisition
#
# Exploratory Data Analysis
#
# Preprocessing
#
# Model Development
#
# Testing
#
# Interpreting The Results
#
# Discussion On Limitations/Issues With Methodologies And Potential Expansions/Fixes
#
# Conclusion
#
# Resources

# %% [markdown]
# # Abstract

# %% [markdown]
# In this notebook we will see the effectiveness of different approaches to dealing with imbalanced data when also having no domain knowledge. Those techniques will be demonstrated in a practical example trying to develop a model that can detect credit card fraud.

# %% [markdown]
# # Data Acquisition

# %% [markdown]
# We will use the data in this kaggle competition https://www.kaggle.com/datasets/whenamancodes/fraud-detection/code?datasetId=2472961&sortBy=voteCount. The dataset contains transactions made by credit cards in September 2013 by European cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-sensitive learning. Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# ### Imports
#
# first our imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import time

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, StratifiedKFold
from sklearn.metrics import f1_score, classification_report, make_scorer

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from mglearn import plots
import warnings

# %%
warnings.filterwarnings("ignore", category=UserWarning)

# %%
#from google.colab import drive 
#drive.mount('/content/gdrive')

# %%
data = pd.read_csv("creditcard.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.473120e-16  8.042109e-16  5.282512e-16  4.456271e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.426896e-15  1.701640e-15 -3.662252e-16 -1.217809e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
def showLabelsCountPlot(data):
    sns.countplot(x='Class', data=data)
    plt.title("Fraud class histogram")
    plt.ylabel("Frequency")
    plt.xlabel("Class")
    plt.show()

# %%
sns.countplot(x='Class', data=data)
plt.title("Fraud class histogram")
plt.ylabel("Frequency")
plt.xlabel("Class")
plt.show()

# %%
np.sum(data.isna().sum() > 0)
# Out:
# 0

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There don't seem to be any strong correlations nor positive or negative this is probably a result of the PCA.

# %%
plt.figure(figsize=(6,4),dpi=200)
sns.histplot(data=data,x='Time',kde=True,bins=25)
plt.title("Time")
# Out:
# Text(0.5, 1.0, 'Time')

# %%
plt.figure(figsize=(6,4),dpi=200)
sns.histplot(data=data,x='Amount',kde=True,bins=25)
plt.title("Amount")
# Out:
# Text(0.5, 1.0, 'Amount')

# %% [markdown]
# The transaction amount is relatively small. There are very few transactions with big amounts the time distribution doesn't give us information that will allow us to make presumptions about the data. Due to the PCA preprocessing we can't really make any a prior assumption about the data. So we so the only thing that we can do to make a better model is to try to find ways to deal with the imbalanced class distribution. The techniques that we will use are going to be :
#
# -Opting for f1 score instead of accuracy.
#
# -Undersample the data
#
# -Oversample the data using NearMiss under-sampling
#
# -Oversample the data using Synthetic Minority Over-sampling
#
# -Oversample the data using Synthetic Minority Over-sampling during the cross validation process

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Spliting

# %% [markdown]
# We split the data into training and testing sets

# %%
attributes = data.drop(labels=["Class", "Amount"], axis=1)

# %%
labels = data["Class"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    attributes, labels, stratify=labels, test_size=0.2, random_state=42)

# %%
print("Shape of training set: ", X_train.shape)
print("Shape of testing set: ", X_test.shape)
# Out:
# Shape of training set:  (227845, 29)
# Shape of testing set:  (56962, 29)

# %%
print(f"train data positives count {sum(y_train.values)}") 
print(f"test data positives count {sum(y_test.values)}")
# Out:
# train data positives count 394
# test data positives count 98

# %% [markdown]
# ### Scaling

# %% [markdown]
# We fit the standard scaler to the training data only in this project we are considering fitting the scaler to any non-training data to be data leakage.
# We scale all the data even the pre-scaled data so that every variable has a normal distribution.

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
def scaleData(data, scaler):
    scaled_data = pd.DataFrame(scaler.transform(data))
    scaled_data.columns = data.columns

    return scaled_data

# %%
X_train_scaled = scaleData(X_train, scaler)

# %%
X_test_scaled = scaleData(X_test, scaler)

# %%
X_test_scaled.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  56962.000000  56962.000000  56962.000000  56962.000000  56962.000000
# mean      -0.007500     -0.002030      0.001458      0.001264      0.000070
# std        0.999960      0.999423      1.006712      1.003183      1.000016
# min       -1.998031    -19.173238    -25.573036    -21.417574     -3.717199
# 25%       -0.858977     -0.471080     -0.362177     -0.584066     -0.603929
# 50%       -0.219182      0.007016      0.042164      0.118846     -0.009511
# 75%        0.931985      0.671272      0.487140      0.679519      0.527829
# max        1.640423      1.252799     10.873297      2.789231      8.568862
#
#                  V5            V6            V7            V8            V9  \
# count  56962.000000  56962.000000  56962.000000  56962.000000  56962.000000
# mean      -0.000633      0.004399     -0.000310      0.001821     -0.003197
# std        1.002464      1.003953      0.994601      1.012000      1.005829
# min      -29.304793    -15.020249    -25.191133    -42.542060     -8.640969
# 25%       -0.500121     -0.575310     -0.449328     -0.176847     -0.597040
# 50%       -0.037891     -0.205314      0.031453      0.015833     -0.049277
# 75%        0.446335      0.303979      0.460224      0.273629      0.539837
# max       20.848943     17.967805     35.572826     15.344455      8.315344
#
#        ...           V19           V20           V21           V22  \
# count  ...  56962.000000  56962.000000  56962.000000  56962.000000
# mean   ...     -0.004076      0.006480     -0.002515     -0.002085
# std    ...      1.000679      1.000767      0.997021      0.999775
# min    ...     -5.388054    -36.336901    -30.964787    -12.245976
# 25%    ...     -0.568197     -0.273938     -0.312672     -0.749125
# 50%    ...     -0.003434     -0.079198     -0.041395      0.010586
# 75%    ...      0.558174      0.175609      0.253217      0.728904
# max    ...      6.869530     34.040278     37.012128     11.398021
#
#                 V23           V24           V25           V26           V27  \
# count  56962.000000  56962.000000  56962.000000  56962.000000  56962.000000
# mean      -0.000402      0.002290      0.006287     -0.001308      0.000870
# std        0.976208      1.002694      1.000401      1.002994      0.983836
# min      -42.636973     -4.662171    -14.379486     -3.850042    -24.314484
# 25%       -0.257461     -0.583210     -0.609301     -0.683258     -0.176023
# 50%       -0.019091      0.069212      0.037378     -0.111932      0.002384
# 75%        0.235553      0.731236      0.681922      0.500435      0.223822
# max       30.287490      6.646304     14.427753      6.465715     25.949859
#
#                 V28
# count  56962.000000
# mean      -0.002351
# std        1.047210
# min      -25.730899
# 25%       -0.163021
# 50%        0.034157
# 75%        0.241028
# max       69.187083
#
# [8 rows x 29 columns]

# %% [markdown]
# ## Under Sample

# %% [markdown]
# The two undersamling techniques we will use random undersamling and undersamling with the NearMiss algorithm.(for more information visit https://imbalanced-learn.org/stable/references/generated/imblearn.under_sampling.NearMiss.html)

# %% [markdown]
# ### Random Under Sample

# %%
def underSampleData(X_train, y_train, positive_label = 1):
    
    positive_count = len(y_train[y_train == positive_label])
    positive_indices = np.array(y_train[y_train == positive_label].index)

    negative_indices = y_train[y_train != positive_label].index

    random_negative_indices = np.random.choice(negative_indices, positive_count, replace = False)
    random_negative_indices = np.array(random_negative_indices)

    under_sample_indices = np.concatenate([positive_indices, random_negative_indices])

    y_train_under_sample = y_train.loc[under_sample_indices]

    X_train_under_sample = X_train.loc[under_sample_indices]

    return X_train_under_sample, y_train_under_sample

# %%
X_train_under_sample, y_train_under_sample = underSampleData(X_train, y_train)

# %%
X_train_under_sample_scaled = scaleData(X_train_under_sample, scaler)

# %%
X_train_under_sample_scaled.describe()
# Out:
#              Time          V1          V2          V3          V4          V5  \
# count  788.000000  788.000000  788.000000  788.000000  788.000000  788.000000
# mean    -0.114817   -1.175604    1.061290   -2.332550    1.623766   -1.144137
# std      1.022033    2.836726    2.254125    4.126407    2.305264    3.031259
# min     -1.986091  -15.596939   -8.693627  -20.526316   -3.289113  -16.023665
# 25%     -1.002380   -1.342645   -0.100816   -3.396208   -0.036450   -1.254444
# 50%     -0.267352   -0.355832    0.559930   -0.903235    0.964814   -0.323629
# 75%      0.891296    0.553218    1.659229    0.207517    3.057853    0.329768
# max      1.618144    1.147866   13.375999    2.241248    8.556395    8.042321
#
#                V6          V7          V8          V9  ...         V19  \
# count  788.000000  788.000000  788.000000  788.000000  ...  788.000000
# mean    -0.558832   -2.231241    0.223365   -1.189431  ...    0.371021
# std      1.257934    4.777353    4.013288    2.116449  ...    1.562378
# min     -4.335905  -35.171457  -34.447787  -12.242932  ...   -4.524434
# 25%     -1.164263   -2.445364   -0.163181   -2.148452  ...   -0.515427
# 50%     -0.508175   -0.488387    0.129054   -0.672152  ...    0.233293
# 75%      0.010899    0.216147    0.686575    0.152433  ...    1.132775
# max      4.864193    4.685343   16.792270    5.351294  ...    5.959479
#
#               V20         V21         V22         V23         V24         V25  \
# count  788.000000  788.000000  788.000000  788.000000  788.000000  788.000000
# mean     0.228614    0.431198    0.035420   -0.061500   -0.074687    0.006507
# std      1.450024    3.673488    1.576265    2.019483    0.885608    1.319424
# min     -5.832320  -31.019299  -12.245976  -30.688319   -3.349874   -9.172358
# 25%     -0.286122   -0.212636   -0.705864   -0.360736   -0.662959   -0.619788
# 50%      0.013169    0.167792    0.026926   -0.034628    0.017109    0.074208
# 75%      0.525818    0.872870    0.783579    0.317462    0.600593    0.745109
# max     14.348654   37.012128   11.521692    9.483629    2.076386    4.237755
#
#               V26         V27         V28
# count  788.000000  788.000000  788.000000
# mean     0.044783    0.214296    0.096464
# std      0.982647    2.455454    1.416832
# min     -2.471738  -17.937316  -12.460413
# 25%     -0.578018   -0.178633   -0.188024
# 50%     -0.054693    0.103995    0.093967
# 75%      0.648453    1.066710    0.684984
# max      5.696032    9.602478    6.322607
#
# [8 rows x 29 columns]

# %%
sns.countplot(x='Class', data=pd.DataFrame(y_train_under_sample))
plt.title("Fraud class histogram")
plt.ylabel("Frequency")
plt.xlabel("Class")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(pd.concat([X_train_under_sample_scaled, pd.DataFrame(y_train_under_sample)], axis = 0).corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Now we see significant correlations seem that the lack of previous correlations was due to the lack positive labels in the data.

# %% [markdown]
# ### Under Sample NearMiss

# %%
nm = NearMiss()

# %%
X_train_under_nm, y_train_under_sample_nm =  nm.fit_resample(X_train, y_train)

# %%
X_train_under_sample_scaled_nm = scaleData(X_train_under_nm, scaler)

# %%
sns.countplot(x='Class', data=pd.DataFrame(y_train_under_sample_nm))
plt.title("Fraud class histogram")
plt.ylabel("Frequency")
plt.xlabel("Class")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(pd.concat([X_train_under_sample_scaled_nm, pd.DataFrame(y_train_under_sample_nm)], axis = 0).corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Again we see similar results.

# %% [markdown]
# ## Undersample + PCA

# %% [markdown]
# Because we saw higher correlations when undersampling the data we will try to perform PCA analysis on the data undersampled data to see what explained variance we will see and to see if we potentially get better results.

# %%
pca = PCA()
pca.fit(X_train_under_sample_scaled)
# Out:
# PCA()

# %%
number_pcs = len(pca.explained_variance_ratio_)
total_explained_variance = np.cumsum(pca.explained_variance_ratio_)

# %%
number_pcs = len(pca.explained_variance_ratio_)
total_explained_variance = np.cumsum(pca.explained_variance_ratio_)

plt.plot(total_explained_variance)
plt.scatter(range(number_pcs), total_explained_variance)
plt.xticks(range(number_pcs))

plt.axhline(0.9, c="r")

plt.xlabel("Number of Components")
plt.ylabel("Variance Explained")
plt.show()

# %% [markdown]
# It seems that we can get 90% explained variance with only 6 components.

# %%
pca = PCA(n_components=6)

# %%
X_train_pca = pca.fit_transform(X_train_under_sample_scaled)

# %%
X_test_pca = pca.transform(X_test_scaled)

# %%
plt.figure(figsize=(8,8),dpi=150)
ax = plt.axes(projection='3d')
ax.scatter3D(X_train_pca[:,0],X_train_pca[:,1],X_train_pca[:,2],c=y_train_under_sample);

# %%
plt.figure(figsize=(8,8),dpi=150)
ax = plt.axes(projection='3d')
ax.scatter3D(X_train_pca[:,3],X_train_pca[:,4],X_train_pca[:,5],c=y_train_under_sample);

# %% [markdown]
# It seems like we are getting some meaningful separation between the classes that might help for a better model.

# %% [markdown]
# ## Over Sample

# %% [markdown]
# We will oversample the data using the Synthetic Minority Over-sampling algorithm before the cross-validation.(for more information visit https://medium.com/@corymaklin/synthetic-minority-over-sampling-technique-smote-7d419696b88c)

# %% [markdown]
# ### SMOTE Over Sample Before CV

# %%
smote = SMOTE()

# %%
X_train_over_smote, y_train_over_smote =  smote.fit_resample(X_train, y_train)

# %%
X_train_over_scaled_smote = scaleData(X_train_over_smote, scaler)

# %%
sns.countplot(x='Class', data=pd.DataFrame(y_train_over_smote))
plt.title("Fraud class histogram")
plt.ylabel("Frequency")
plt.xlabel("Class")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(pd.concat([X_train_over_scaled_smote, pd.DataFrame(y_train_over_smote)], axis = 0).corr(), cmap='coolwarm')
plt.show()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### SMOTE Over Sample During CV

# %% [markdown]
# The previous oversampling technique can potentially produce extreme overfitting. Because you will be directly influencing the validation set before implementing cross-validation causing a "data leakage" problem.
#
# ![image](oversamlingWrong.jpg)
#
#
#
# To fix this problem we need to do the smote oversampling the cross-validation process this will be show in the model development section below.
#
# As shown below by performing SMOTE oversampling during cross validation and not prior to the cross validation process. Synthetic data are created only for the training set without affecting the validation set.
#
# ![image](oversamplingRight.jpg)

# %% [markdown]
# # Model Development

# %% [markdown]
# We shall use grid search cross validation to with same parameters to find the best how will the different sampling techniques perform and how will the optimal parameters change.(Note that you can just use the "unPickleModels" function to load the already trained models.)

# %% [markdown]
# ## Utilities ----------------------------------------------------------------|
#
# These are some helper functions to make the training process easier.

# %%
def pickleModels(models, folder):
    pickle_out = open((folder + ".pickle"), "wb")
    pickle.dump(models, pickle_out)
    pickle_out.close()

# %%
def unPickleModels(folder):
    pickle_in = open((folder + ".pickle"), "rb")
    models = pickle.load(pickle_in)
    pickle_in.close()

    return models

# %%
def trainModels(attributes, labels, models, param_grids, scoring = make_scorer(f1_score, pos_label = 1),cv = 5):
    GridSearchModels = {}

    for model, param_grid in zip(models, param_grids):
        
        grid_search = GridSearchCV(model, param_grid, scoring = scoring,cv = cv)
        grid_search.fit(attributes, labels)
        GridSearchModels[grid_search.estimator.__class__.__name__] = grid_search

        print(f"{grid_search.estimator.__class__.__name__} model fitted successfully")
    
    return GridSearchModels

# %%
def getModelsClassificationReport(attributes, labels, models, scoring = classification_report):
    
    result = pd.DataFrame({'Model' : []})

    for model in models:

        print(f"Model : {model}")
        print(f"Best params : {models[model].best_params_}")

        start = time.time()
        score = scoring(models[model].predict(attributes), labels, output_dict=True)
        end = time.time()

        result = pd.DataFrame(pd.concat([result, pd.DataFrame(score).transpose()], axis=0)).fillna(model)
        
        print(f"Took {end - start} seconds\n")

    return result.round(decimals =2)

# %%
def trainModelsSMOTE(attributes, labels, models, param_grids, scoring = make_scorer(f1_score, pos_label = 1),cv = 5):
    
    def addUnderscore(dict):
        res = {}
        for k, v in dict.items():
            res["classification__"+k] = v
        return res

    smote_models = [Pipeline([("sampling", SMOTE()), ("classification", model)]) for model in models]
    smote_param_grids = [addUnderscore(param_grid) for param_grid in param_grids]
    GridSearchModels = {}

    for model, param_grid in zip(smote_models, smote_param_grids):
        grid_search = GridSearchCV(model, param_grid, scoring = scoring,cv = cv)
        grid_search.fit(attributes, labels)
        GridSearchModels[grid_search.estimator['classification'].__class__.__name__] = grid_search
        pickleModels(grid_search, grid_search.estimator['classification'].__class__.__name__)
        print(f"{grid_search.estimator['classification'].__class__.__name__} model fitted successfully")
    
    return GridSearchModels

# %% [markdown]
# ## Training

# %%
scorer = make_scorer(f1_score, pos_label = 1)

# %%
k_fold = StratifiedKFold(n_splits= 5)

# %%
linear_model_param_grid = {
    'solver': ["saga"],
    'C': [0.01, 0.1, 1, 10],
    'l1_ratio': [0, .1, .5, .7, .9, .99],
    "penalty": ["elasticnet"],
    "max_iter" : [100000]}

# %%
KNN_param_grid = {"n_neighbors": list(range(1, 31, 5))}

# %%
SVC_param_grid = {'C': [0.001,0.01,0.1,0.5, 0,7 ,1], 'kernel': ['rbf', 'linear']}

# %%
tree_param_grid = {"max_depth": list(range(2,7,2)), 
              "min_samples_leaf": list(range(2,7,2))
              ,"max_leaf_nodes":[ 15, 20]}

# %%
forest_param_grid = {
    "n_estimators": [ 300, 400],
    "max_depth": [ 20, 50, 100]
}

# %%
ada_param_grid = {
    "n_estimators": [ 200, 300, 400],
    "learning_rate": [0.001, 0.01, 0.1, 0.5]
}

# %%
models = [LogisticRegression(), KNeighborsClassifier(), SVC(), DecisionTreeClassifier(), RandomForestClassifier(), AdaBoostClassifier()]
param_grids = [linear_model_param_grid, KNN_param_grid, SVC_param_grid, tree_param_grid, forest_param_grid, ada_param_grid]
scoring = make_scorer(f1_score, pos_label = 1)
cv = 5

# %%
#under_sample_models = trainModels(X_train_under_sample_scaled, y_train_under_sample, models, param_grids, scoring, cv )

# %%
#pickleModels(under_sample_models, "under_sample_models")

# %%
under_sample_models = unPickleModels("under_sample_models")

# %%
cl_report_under_sample_models_train = getModelsClassificationReport(X_train_under_sample_scaled, y_train_under_sample, under_sample_models)
# Out:
# Model : LogisticRegression
# Best params : {'C': 1, 'l1_ratio': 0.1, 'max_iter': 100000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.00600123405456543 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 0.06016993522644043 seconds
#
# Model : SVC
# Best params : {'C': 0.1, 'kernel': 'linear'}
# Took 0.004999876022338867 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 4, 'max_leaf_nodes': 15, 'min_samples_leaf': 2}
# Took 0.0029997825622558594 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 50, 'n_estimators': 300}
# Took 0.03100299835205078 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.01, 'n_estimators': 400}
# Took 0.0522768497467041 seconds

# %%
cl_report_under_sample_models_train
# Out:
#                                Model  precision  recall  f1-score  support
# 0                 LogisticRegression       0.95    0.94      0.94   402.00
# 1                 LogisticRegression       0.93    0.95      0.94   386.00
# accuracy          LogisticRegression       0.94    0.94      0.94     0.94
# macro avg         LogisticRegression       0.94    0.94      0.94   788.00
# weighted avg      LogisticRegression       0.94    0.94      0.94   788.00
# 0               KNeighborsClassifier       0.98    0.90      0.94   430.00
# 1               KNeighborsClassifier       0.89    0.98      0.93   358.00
# accuracy        KNeighborsClassifier       0.93    0.93      0.93     0.93
# macro avg       KNeighborsClassifier       0.93    0.94      0.93   788.00
# weighted avg    KNeighborsClassifier       0.94    0.93      0.93   788.00
# 0                                SVC       0.96    0.93      0.95   408.00
# 1                                SVC       0.93    0.96      0.94   380.00
# accuracy                         SVC       0.94    0.94      0.94     0.94
# macro avg                        SVC       0.94    0.94      0.94   788.00
# weighted avg                     SVC       0.94    0.94      0.94   788.00
# 0             DecisionTreeClassifier       0.95    0.94      0.94   398.00
# 1             DecisionTreeClassifier       0.94    0.95      0.94   390.00
# accuracy      DecisionTreeClassifier       0.94    0.94      0.94     0.94
# macro avg     DecisionTreeClassifier       0.94    0.94      0.94   788.00
# weighted avg  DecisionTreeClassifier       0.94    0.94      0.94   788.00
# 0             RandomForestClassifier       0.97    1.00      0.99   383.00
# 1             RandomForestClassifier       1.00    0.97      0.99   405.00
# accuracy      RandomForestClassifier       0.99    0.99      0.99     0.99
# macro avg     RandomForestClassifier       0.99    0.99      0.99   788.00
# weighted avg  RandomForestClassifier       0.99    0.99      0.99   788.00
# 0                 AdaBoostClassifier       0.97    0.91      0.94   421.00
# 1                 AdaBoostClassifier       0.90    0.97      0.93   367.00
# accuracy          AdaBoostClassifier       0.94    0.94      0.94     0.94
# macro avg         AdaBoostClassifier       0.94    0.94      0.94   788.00
# weighted avg      AdaBoostClassifier       0.94    0.94      0.94   788.00

# %%
cl_report_under_sample_models_train = getModelsClassificationReport(X_train_under_sample_scaled, y_train_under_sample, under_sample_models)
# Out:
# Model : LogisticRegression
# Best params : {'C': 1, 'l1_ratio': 0.1, 'max_iter': 100000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.003999948501586914 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 0.06078076362609863 seconds
#
# Model : SVC
# Best params : {'C': 0.1, 'kernel': 'linear'}
# Took 0.00599980354309082 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 4, 'max_leaf_nodes': 15, 'min_samples_leaf': 2}
# Took 0.003999233245849609 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 50, 'n_estimators': 300}
# Took 0.028001070022583008 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.01, 'n_estimators': 400}
# Took 0.0508272647857666 seconds

# %%
cl_report_under_sample_models_train
# Out:
#                                Model  precision  recall  f1-score  support
# 0                 LogisticRegression       0.95    0.94      0.94   402.00
# 1                 LogisticRegression       0.93    0.95      0.94   386.00
# accuracy          LogisticRegression       0.94    0.94      0.94     0.94
# macro avg         LogisticRegression       0.94    0.94      0.94   788.00
# weighted avg      LogisticRegression       0.94    0.94      0.94   788.00
# 0               KNeighborsClassifier       0.98    0.90      0.94   430.00
# 1               KNeighborsClassifier       0.89    0.98      0.93   358.00
# accuracy        KNeighborsClassifier       0.93    0.93      0.93     0.93
# macro avg       KNeighborsClassifier       0.93    0.94      0.93   788.00
# weighted avg    KNeighborsClassifier       0.94    0.93      0.93   788.00
# 0                                SVC       0.96    0.93      0.95   408.00
# 1                                SVC       0.93    0.96      0.94   380.00
# accuracy                         SVC       0.94    0.94      0.94     0.94
# macro avg                        SVC       0.94    0.94      0.94   788.00
# weighted avg                     SVC       0.94    0.94      0.94   788.00
# 0             DecisionTreeClassifier       0.95    0.94      0.94   398.00
# 1             DecisionTreeClassifier       0.94    0.95      0.94   390.00
# accuracy      DecisionTreeClassifier       0.94    0.94      0.94     0.94
# macro avg     DecisionTreeClassifier       0.94    0.94      0.94   788.00
# weighted avg  DecisionTreeClassifier       0.94    0.94      0.94   788.00
# 0             RandomForestClassifier       0.97    1.00      0.99   383.00
# 1             RandomForestClassifier       1.00    0.97      0.99   405.00
# accuracy      RandomForestClassifier       0.99    0.99      0.99     0.99
# macro avg     RandomForestClassifier       0.99    0.99      0.99   788.00
# weighted avg  RandomForestClassifier       0.99    0.99      0.99   788.00
# 0                 AdaBoostClassifier       0.97    0.91      0.94   421.00
# 1                 AdaBoostClassifier       0.90    0.97      0.93   367.00
# accuracy          AdaBoostClassifier       0.94    0.94      0.94     0.94
# macro avg         AdaBoostClassifier       0.94    0.94      0.94   788.00
# weighted avg      AdaBoostClassifier       0.94    0.94      0.94   788.00

# %%
#under_sample_models_nm = trainModels(X_train_under_sample_scaled_nm, y_train_under_sample_nm, models, param_grids, scoring, cv )

# %%
#pickleModels(under_sample_models_nm, "under_sample_models_nm")

# %%
under_sample_models_nm = unPickleModels("under_sample_models_nm")

# %%
cl_report_under_sample_models_nm_train = getModelsClassificationReport(X_train_under_sample_scaled_nm, y_train_under_sample_nm, under_sample_models_nm)
# Out:
# Model : LogisticRegression
# Best params : {'C': 0.1, 'l1_ratio': 0.1, 'max_iter': 100000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.003911733627319336 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 0.06285810470581055 seconds
#
# Model : SVC
# Best params : {'C': 0.1, 'kernel': 'linear'}
# Took 0.004999876022338867 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 6, 'max_leaf_nodes': 20, 'min_samples_leaf': 2}
# Took 0.003000020980834961 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 20, 'n_estimators': 400}
# Took 0.03100419044494629 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.5, 'n_estimators': 300}
# Took 0.036414384841918945 seconds

# %%
cl_report_under_sample_models_nm_train
# Out:
#                                Model  precision  recall  f1-score  support
# 0                 LogisticRegression       0.99    0.92      0.95   423.00
# 1                 LogisticRegression       0.91    0.99      0.95   365.00
# accuracy          LogisticRegression       0.95    0.95      0.95     0.95
# macro avg         LogisticRegression       0.95    0.95      0.95   788.00
# weighted avg      LogisticRegression       0.95    0.95      0.95   788.00
# 0               KNeighborsClassifier       0.99    0.90      0.94   432.00
# 1               KNeighborsClassifier       0.89    0.99      0.94   356.00
# accuracy        KNeighborsClassifier       0.94    0.94      0.94     0.94
# macro avg       KNeighborsClassifier       0.94    0.94      0.94   788.00
# weighted avg    KNeighborsClassifier       0.94    0.94      0.94   788.00
# 0                                SVC       0.99    0.93      0.96   420.00
# 1                                SVC       0.93    0.99      0.96   368.00
# accuracy                         SVC       0.96    0.96      0.96     0.96
# macro avg                        SVC       0.96    0.96      0.96   788.00
# weighted avg                     SVC       0.96    0.96      0.96   788.00
# 0             DecisionTreeClassifier       1.00    0.95      0.97   415.00
# 1             DecisionTreeClassifier       0.95    1.00      0.97   373.00
# accuracy      DecisionTreeClassifier       0.97    0.97      0.97     0.97
# macro avg     DecisionTreeClassifier       0.97    0.97      0.97   788.00
# weighted avg  DecisionTreeClassifier       0.97    0.97      0.97   788.00
# 0             RandomForestClassifier       1.00    1.00      1.00   394.00
# 1             RandomForestClassifier       1.00    1.00      1.00   394.00
# accuracy      RandomForestClassifier       1.00    1.00      1.00     1.00
# macro avg     RandomForestClassifier       1.00    1.00      1.00   788.00
# weighted avg  RandomForestClassifier       1.00    1.00      1.00   788.00
# 0                 AdaBoostClassifier       1.00    1.00      1.00   394.00
# 1                 AdaBoostClassifier       1.00    1.00      1.00   394.00
# accuracy          AdaBoostClassifier       1.00    1.00      1.00     1.00
# macro avg         AdaBoostClassifier       1.00    1.00      1.00   788.00
# weighted avg      AdaBoostClassifier       1.00    1.00      1.00   788.00

# %%
#under_sample_models_pca = trainModels(X_train_pca, y_train_under_sample, models, param_grids, scoring, cv )

# %%
#pickleModels(under_sample_models_pca, "under_sample_models_pca")

# %%
under_sample_models_pca = unPickleModels("under_sample_models_pca")

# %%
cl_report_under_sample_models_pca_train = getModelsClassificationReport(X_train_pca, y_train_under_sample, under_sample_models_pca)
# Out:
# Model : LogisticRegression
# Best params : {'C': 0.1, 'l1_ratio': 0.5, 'max_iter': 100000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.006001710891723633 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 0.014293193817138672 seconds
#
# Model : SVC
# Best params : {'C': 1, 'kernel': 'rbf'}
# Took 0.008057355880737305 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 4, 'max_leaf_nodes': 15, 'min_samples_leaf': 2}
# Took 0.0029296875 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 50, 'n_estimators': 400}
# Took 0.030579566955566406 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.01, 'n_estimators': 300}
# Took 0.027541637420654297 seconds

# %% [markdown]
# We shall also train a models without performing any sampling. Those models are going to be out "control" models. We will use them to see how much we actually benefit from these sampling techniques compared to just using the f1 scoring system. Note that we are using StratifiedKFold cross-validation to so that the validation sets are balanced in every fold.

# %% [markdown]
# Using stratified fold we will make sure that in each validation fold the classes will be balanced so that we don't overfit to the majority class.

# %%
plots.plot_stratified_cross_validation()

# %%
#no_sampling_models = trainModels(X_train_scaled, y_train, models, param_grids, scoring, cv=StratifiedKFold(n_splits= 2))

# %%
#pickleModels(no_sampling_models, "no_sampling_models")

# %%
no_sampling_models = unPickleModels("no_sampling_models")

# %%
cl_report_no_sampling_models_train = getModelsClassificationReport(X_train_scaled, y_train, no_sampling_models)
# Out:
# Model : LogisticRegression
# Best params : {'C': 1, 'l1_ratio': 0.5, 'max_iter': 10000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.1730971336364746 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 743.7105803489685 seconds
#
# Model : SVC
# Best params : {'C': 0.1, 'kernel': 'linear'}
# Took 1.3750910758972168 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 4, 'max_leaf_nodes': 20, 'min_samples_leaf': 4}
# Took 0.1766195297241211 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 100, 'n_estimators': 100}
# Took 1.6998682022094727 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.5, 'n_estimators': 400}
# Took 10.549992561340332 seconds

# %%
cl_report_no_sampling_models_train
# Out:
#                                Model  precision  recall  f1-score   support
# 0                 LogisticRegression       1.00    1.00      1.00  227563.0
# 1                 LogisticRegression       0.64    0.89      0.74     282.0
# accuracy          LogisticRegression       1.00    1.00      1.00       1.0
# macro avg         LogisticRegression       0.82    0.94      0.87  227845.0
# weighted avg      LogisticRegression       1.00    1.00      1.00  227845.0
# 0               KNeighborsClassifier       1.00    1.00      1.00  227517.0
# 1               KNeighborsClassifier       0.76    0.91      0.83     328.0
# accuracy        KNeighborsClassifier       1.00    1.00      1.00       1.0
# macro avg       KNeighborsClassifier       0.88    0.96      0.92  227845.0
# weighted avg    KNeighborsClassifier       1.00    1.00      1.00  227845.0
# 0                                SVC       1.00    1.00      1.00  227479.0
# 1                                SVC       0.79    0.85      0.82     366.0
# accuracy                         SVC       1.00    1.00      1.00       1.0
# macro avg                        SVC       0.90    0.93      0.91  227845.0
# weighted avg                     SVC       1.00    1.00      1.00  227845.0
# 0             DecisionTreeClassifier       1.00    1.00      1.00  227498.0
# 1             DecisionTreeClassifier       0.79    0.90      0.84     347.0
# accuracy      DecisionTreeClassifier       1.00    1.00      1.00       1.0
# macro avg     DecisionTreeClassifier       0.90    0.95      0.92  227845.0
# weighted avg  DecisionTreeClassifier       1.00    1.00      1.00  227845.0
# 0             RandomForestClassifier       1.00    1.00      1.00  227451.0
# 1             RandomForestClassifier       1.00    1.00      1.00     394.0
# accuracy      RandomForestClassifier       1.00    1.00      1.00       1.0
# macro avg     RandomForestClassifier       1.00    1.00      1.00  227845.0
# weighted avg  RandomForestClassifier       1.00    1.00      1.00  227845.0
# 0                 AdaBoostClassifier       1.00    1.00      1.00  227512.0
# 1                 AdaBoostClassifier       0.80    0.95      0.87     333.0
# accuracy          AdaBoostClassifier       1.00    1.00      1.00       1.0
# macro avg         AdaBoostClassifier       0.90    0.97      0.93  227845.0
# weighted avg      AdaBoostClassifier       1.00    1.00      1.00  227845.0

# %%
#over_before_sampling_models = trainModels(X_train_over_scaled_smote, y_train_over_smote, models, param_grids, scoring, cv)

# %%
#pickleModels(over_before_sampling_models, "over_before_sampling_models")

# %%
over_before_sampling_models = unPickleModels("over_before_sampling_models")

# %%
cl_report_over_before_sampling_models_train = getModelsClassificationReport(X_train_over_scaled_smote, y_train_over_smote, over_before_sampling_models)
# Out:
# Model : LogisticRegression
# Best params : {'C': 1, 'l1_ratio': 0, 'max_iter': 100000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.4005608558654785 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 9.03423261642456 seconds
#
# Model : SVC
# Best params : {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# Took 1.1073689460754395 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 4, 'max_leaf_nodes': 10, 'min_samples_leaf': 3}
# Took 0.3930473327636719 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 20, 'n_estimators': 400}
# Took 8.026644468307495 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.1, 'n_estimators': 100}
# Took 5.424058675765991 seconds

# %%
cl_report_over_before_sampling_models_train
# Out:
#                                Model  precision  recall  f1-score    support
# 0                 LogisticRegression       0.96    0.98      0.97  223659.00
# 1                 LogisticRegression       0.98    0.96      0.97  231243.00
# accuracy          LogisticRegression       0.97    0.97      0.97       0.97
# macro avg         LogisticRegression       0.97    0.97      0.97  454902.00
# weighted avg      LogisticRegression       0.97    0.97      0.97  454902.00
# 0               KNeighborsClassifier       0.99    0.92      0.95  244505.00
# 1               KNeighborsClassifier       0.91    0.99      0.95  210397.00
# accuracy        KNeighborsClassifier       0.95    0.95      0.95       0.95
# macro avg       KNeighborsClassifier       0.95    0.95      0.95  454902.00
# weighted avg    KNeighborsClassifier       0.95    0.95      0.95  454902.00
# 0                                SVC       0.97    0.97      0.97  227510.00
# 1                                SVC       0.97    0.97      0.97  227392.00
# accuracy                         SVC       0.97    0.97      0.97       0.97
# macro avg                        SVC       0.97    0.97      0.97  454902.00
# weighted avg                     SVC       0.97    0.97      0.97  454902.00
# 0             DecisionTreeClassifier       0.93    0.95      0.94  220961.00
# 1             DecisionTreeClassifier       0.95    0.93      0.94  233941.00
# accuracy      DecisionTreeClassifier       0.94    0.94      0.94       0.94
# macro avg     DecisionTreeClassifier       0.94    0.94      0.94  454902.00
# weighted avg  DecisionTreeClassifier       0.94    0.94      0.94  454902.00
# 0             RandomForestClassifier       0.97    0.97      0.97  226906.00
# 1             RandomForestClassifier       0.97    0.97      0.97  227996.00
# accuracy      RandomForestClassifier       0.97    0.97      0.97       0.97
# macro avg     RandomForestClassifier       0.97    0.97      0.97  454902.00
# weighted avg  RandomForestClassifier       0.97    0.97      0.97  454902.00
# 0                 AdaBoostClassifier       0.97    0.96      0.96  230686.00
# 1                 AdaBoostClassifier       0.96    0.97      0.96  224216.00
# accuracy          AdaBoostClassifier       0.96    0.96      0.96       0.96
# macro avg         AdaBoostClassifier       0.96    0.96      0.96  454902.00
# weighted avg      AdaBoostClassifier       0.96    0.96      0.96  454902.00

# %% [markdown]
# Oversampling during cross-validation

# %%
#smote_during_cv_models = trainModelsSMOTE(X_train_scaled, y_train, models, param_grids, scoring, cv )

# %%
#pickleModels(smote_during_cv_models, "smote_during_cv_models")

# %%
smote_during_cv_models = unPickleModels("smote_during_cv_models")

# %%
cl_report_smote_during_cv_models_train = getModelsClassificationReport(X_train_scaled, y_train, smote_during_cv_models)
# Out:
# Model : LogisticRegression
# Best params : {'classification__C': 0.01, 'classification__l1_ratio': 0.9, 'classification__max_iter': 100000, 'classification__penalty': 'elasticnet', 'classification__solver': 'saga'}
# Took 0.1679682731628418 seconds
#
# Model : KNeighborsClassifier
# Best params : {'classification__n_neighbors': 1}
# Took 51.96932816505432 seconds
#
# Model : SVC
# Best params : {'classification__C': 0.001, 'classification__kernel': 'rbf'}
# Took 1204.406974554062 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'classification__max_depth': 2, 'classification__max_leaf_nodes': 20, 'classification__min_samples_leaf': 2}
# Took 0.20218682289123535 seconds
#
# Model : RandomForestClassifier
# Best params : {'classification__max_depth': 100, 'classification__n_estimators': 300}
# Took 6.05717658996582 seconds
#
# Model : AdaBoostClassifier
# Best params : {'classification__learning_rate': 0.5, 'classification__n_estimators': 400}
# Took 12.824611186981201 seconds

# %%
cl_report_smote_during_cv_models_train
# Out:
#                                Model  precision  recall  f1-score    support
# 0                 LogisticRegression       0.97    1.00      0.99  221669.00
# 1                 LogisticRegression       0.93    0.06      0.11    6176.00
# accuracy          LogisticRegression       0.97    0.97      0.97       0.97
# macro avg         LogisticRegression       0.95    0.53      0.55  227845.00
# weighted avg      LogisticRegression       0.97    0.97      0.96  227845.00
# 0               KNeighborsClassifier       1.00    1.00      1.00  227451.00
# 1               KNeighborsClassifier       1.00    1.00      1.00     394.00
# accuracy        KNeighborsClassifier       1.00    1.00      1.00       1.00
# macro avg       KNeighborsClassifier       1.00    1.00      1.00  227845.00
# weighted avg    KNeighborsClassifier       1.00    1.00      1.00  227845.00
# 0                                SVC       0.99    1.00      0.99  224592.00
# 1                                SVC       0.88    0.11      0.19    3253.00
# accuracy                         SVC       0.99    0.99      0.99       0.99
# macro avg                        SVC       0.93    0.55      0.59  227845.00
# weighted avg                     SVC       0.99    0.99      0.98  227845.00
# 0             DecisionTreeClassifier       0.98    1.00      0.99  223112.00
# 1             DecisionTreeClassifier       0.86    0.07      0.13    4733.00
# accuracy      DecisionTreeClassifier       0.98    0.98      0.98       0.98
# macro avg     DecisionTreeClassifier       0.92    0.54      0.56  227845.00
# weighted avg  DecisionTreeClassifier       0.98    0.98      0.97  227845.00
# 0             RandomForestClassifier       1.00    1.00      1.00  227451.00
# 1             RandomForestClassifier       1.00    1.00      1.00     394.00
# accuracy      RandomForestClassifier       1.00    1.00      1.00       1.00
# macro avg     RandomForestClassifier       1.00    1.00      1.00  227845.00
# weighted avg  RandomForestClassifier       1.00    1.00      1.00  227845.00
# 0                 AdaBoostClassifier       0.99    1.00      0.99  224856.00
# 1                 AdaBoostClassifier       0.97    0.13      0.23    2989.00
# accuracy          AdaBoostClassifier       0.99    0.99      0.99       0.99
# macro avg         AdaBoostClassifier       0.98    0.56      0.61  227845.00
# weighted avg      AdaBoostClassifier       0.99    0.99      0.98  227845.00

# %% [markdown]
# # Testing

# %%
cl_report_under_sample_models_test = getModelsClassificationReport(X_test_scaled, y_test, under_sample_models)
# Out:
# Model : LogisticRegression
# Best params : {'C': 1, 'l1_ratio': 0.1, 'max_iter': 100000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.05640411376953125 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 0.7426228523254395 seconds
#
# Model : SVC
# Best params : {'C': 0.1, 'kernel': 'linear'}
# Took 0.13607168197631836 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 4, 'max_leaf_nodes': 15, 'min_samples_leaf': 2}
# Took 0.03759121894836426 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 50, 'n_estimators': 300}
# Took 1.2067177295684814 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.01, 'n_estimators': 400}
# Took 3.108192205429077 seconds

# %%
cl_report_under_sample_models_test
# Out:
#                                Model  precision  recall  f1-score   support
# 0                 LogisticRegression       0.96    1.00      0.98  54748.00
# 1                 LogisticRegression       0.92    0.04      0.08   2214.00
# accuracy          LogisticRegression       0.96    0.96      0.96      0.96
# macro avg         LogisticRegression       0.94    0.52      0.53  56962.00
# weighted avg      LogisticRegression       0.96    0.96      0.95  56962.00
# 0               KNeighborsClassifier       0.99    1.00      0.99  56069.00
# 1               KNeighborsClassifier       0.89    0.10      0.18    893.00
# accuracy        KNeighborsClassifier       0.99    0.99      0.99      0.99
# macro avg       KNeighborsClassifier       0.94    0.55      0.58  56962.00
# weighted avg    KNeighborsClassifier       0.98    0.99      0.98  56962.00
# 0                                SVC       0.97    1.00      0.98  55082.00
# 1                                SVC       0.91    0.05      0.09   1880.00
# accuracy                         SVC       0.97    0.97      0.97      0.97
# macro avg                        SVC       0.94    0.52      0.54  56962.00
# weighted avg                     SVC       0.97    0.97      0.95  56962.00
# 0             DecisionTreeClassifier       0.95    1.00      0.97  54081.00
# 1             DecisionTreeClassifier       0.89    0.03      0.06   2881.00
# accuracy      DecisionTreeClassifier       0.95    0.95      0.95      0.95
# macro avg     DecisionTreeClassifier       0.92    0.51      0.52  56962.00
# weighted avg  DecisionTreeClassifier       0.95    0.95      0.93  56962.00
# 0             RandomForestClassifier       0.97    1.00      0.98  55060.00
# 1             RandomForestClassifier       0.91    0.05      0.09   1902.00
# accuracy      RandomForestClassifier       0.97    0.97      0.97      0.97
# macro avg     RandomForestClassifier       0.94    0.52      0.54  56962.00
# weighted avg  RandomForestClassifier       0.97    0.97      0.95  56962.00
# 0                 AdaBoostClassifier       0.98    1.00      0.99  55456.00
# 1                 AdaBoostClassifier       0.90    0.06      0.11   1506.00
# accuracy          AdaBoostClassifier       0.97    0.97      0.97      0.97
# macro avg         AdaBoostClassifier       0.94    0.53      0.55  56962.00
# weighted avg      AdaBoostClassifier       0.97    0.97      0.96  56962.00

# %%
cl_report_under_sample_models_nm_test = getModelsClassificationReport(X_test_scaled, y_test, under_sample_models_nm)
# Out:
# Model : LogisticRegression
# Best params : {'C': 0.1, 'l1_ratio': 0.1, 'max_iter': 100000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.06642436981201172 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 0.82509446144104 seconds
#
# Model : SVC
# Best params : {'C': 0.1, 'kernel': 'linear'}
# Took 0.13883185386657715 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 6, 'max_leaf_nodes': 20, 'min_samples_leaf': 2}
# Took 0.05208325386047363 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 20, 'n_estimators': 400}
# Took 1.3463773727416992 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.5, 'n_estimators': 300}
# Took 2.3456900119781494 seconds

# %%
cl_report_under_sample_models_nm_test
# Out:
#                                Model  precision  recall  f1-score   support
# 0                 LogisticRegression       0.97    1.00      0.99  55349.00
# 1                 LogisticRegression       0.92    0.06      0.11   1613.00
# accuracy          LogisticRegression       0.97    0.97      0.97      0.97
# macro avg         LogisticRegression       0.95    0.53      0.55  56962.00
# weighted avg      LogisticRegression       0.97    0.97      0.96  56962.00
# 0               KNeighborsClassifier       0.99    1.00      0.99  56076.00
# 1               KNeighborsClassifier       0.91    0.10      0.18    886.00
# accuracy        KNeighborsClassifier       0.99    0.99      0.99      0.99
# macro avg       KNeighborsClassifier       0.95    0.55      0.59  56962.00
# weighted avg    KNeighborsClassifier       0.98    0.99      0.98  56962.00
# 0                                SVC       0.96    1.00      0.98  54506.00
# 1                                SVC       0.92    0.04      0.07   2456.00
# accuracy                         SVC       0.96    0.96      0.96      0.96
# macro avg                        SVC       0.94    0.52      0.52  56962.00
# weighted avg                     SVC       0.96    0.96      0.94  56962.00
# 0             DecisionTreeClassifier       0.73    1.00      0.84  41293.00
# 1             DecisionTreeClassifier       0.91    0.01      0.01  15669.00
# accuracy      DecisionTreeClassifier       0.73    0.73      0.73      0.73
# macro avg     DecisionTreeClassifier       0.82    0.50      0.43  56962.00
# weighted avg  DecisionTreeClassifier       0.78    0.73      0.61  56962.00
# 0             RandomForestClassifier       0.73    1.00      0.84  41333.00
# 1             RandomForestClassifier       0.95    0.01      0.01  15629.00
# accuracy      RandomForestClassifier       0.73    0.73      0.73      0.73
# macro avg     RandomForestClassifier       0.84    0.50      0.43  56962.00
# weighted avg  RandomForestClassifier       0.79    0.73      0.61  56962.00
# 0                 AdaBoostClassifier       0.69    1.00      0.82  39373.00
# 1                 AdaBoostClassifier       0.96    0.01      0.01  17589.00
# accuracy          AdaBoostClassifier       0.69    0.69      0.69      0.69
# macro avg         AdaBoostClassifier       0.83    0.50      0.41  56962.00
# weighted avg      AdaBoostClassifier       0.77    0.69      0.57  56962.00

# %%
cl_report_under_sample_models_pca_test = getModelsClassificationReport(X_test_pca, y_test, under_sample_models_pca)
# Out:
# Model : LogisticRegression
# Best params : {'C': 0.1, 'l1_ratio': 0.5, 'max_iter': 100000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.0391535758972168 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 1.3342421054840088 seconds
#
# Model : SVC
# Best params : {'C': 1, 'kernel': 'rbf'}
# Took 1.0151519775390625 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 4, 'max_leaf_nodes': 15, 'min_samples_leaf': 2}
# Took 0.09403467178344727 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 50, 'n_estimators': 400}
# Took 1.835845708847046 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.01, 'n_estimators': 300}
# Took 2.1721503734588623 seconds

# %%
cl_report_under_sample_models_pca_test
# Out:
#                                Model  precision  recall  f1-score   support
# 0                 LogisticRegression       0.98    1.00      0.99  56004.00
# 1                 LogisticRegression       0.89    0.09      0.16    958.00
# accuracy          LogisticRegression       0.98    0.98      0.98      0.98
# macro avg         LogisticRegression       0.94    0.55      0.58  56962.00
# weighted avg      LogisticRegression       0.98    0.98      0.98  56962.00
# 0               KNeighborsClassifier       0.98    1.00      0.99  55556.00
# 1               KNeighborsClassifier       0.90    0.06      0.12   1406.00
# accuracy        KNeighborsClassifier       0.98    0.98      0.98      0.98
# macro avg       KNeighborsClassifier       0.94    0.53      0.55  56962.00
# weighted avg    KNeighborsClassifier       0.97    0.98      0.97  56962.00
# 0                                SVC       0.99    1.00      0.99  56163.00
# 1                                SVC       0.89    0.11      0.19    799.00
# accuracy                         SVC       0.99    0.99      0.99      0.99
# macro avg                        SVC       0.94    0.55      0.59  56962.00
# weighted avg                     SVC       0.99    0.99      0.98  56962.00
# 0             DecisionTreeClassifier       0.95    1.00      0.98  54176.00
# 1             DecisionTreeClassifier       0.90    0.03      0.06   2786.00
# accuracy      DecisionTreeClassifier       0.95    0.95      0.95      0.95
# macro avg     DecisionTreeClassifier       0.93    0.52      0.52  56962.00
# weighted avg  DecisionTreeClassifier       0.95    0.95      0.93  56962.00
# 0             RandomForestClassifier       0.96    1.00      0.98  54566.00
# 1             RandomForestClassifier       0.92    0.04      0.07   2396.00
# accuracy      RandomForestClassifier       0.96    0.96      0.96      0.96
# macro avg     RandomForestClassifier       0.94    0.52      0.53  56962.00
# weighted avg  RandomForestClassifier       0.96    0.96      0.94  56962.00
# 0                 AdaBoostClassifier       0.97    1.00      0.99  55233.00
# 1                 AdaBoostClassifier       0.91    0.05      0.10   1729.00
# accuracy          AdaBoostClassifier       0.97    0.97      0.97      0.97
# macro avg         AdaBoostClassifier       0.94    0.53      0.54  56962.00
# weighted avg      AdaBoostClassifier       0.97    0.97      0.96  56962.00

# %%
cl_report_no_sampling_models_test = getModelsClassificationReport(X_test_scaled, y_test, no_sampling_models)
# Out:
# Model : LogisticRegression
# Best params : {'C': 1, 'l1_ratio': 0.5, 'max_iter': 10000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.04140186309814453 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 198.171537399292 seconds
#
# Model : SVC
# Best params : {'C': 0.1, 'kernel': 'linear'}
# Took 0.3402743339538574 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 4, 'max_leaf_nodes': 20, 'min_samples_leaf': 4}
# Took 0.03504586219787598 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 100, 'n_estimators': 100}
# Took 0.41689300537109375 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.5, 'n_estimators': 400}
# Took 2.7296266555786133 seconds

# %%
cl_report_no_sampling_models_test
# Out:
#                                Model  precision  recall  f1-score  support
# 0                 LogisticRegression       1.00    1.00      1.00  56886.0
# 1                 LogisticRegression       0.64    0.83      0.72     76.0
# accuracy          LogisticRegression       1.00    1.00      1.00      1.0
# macro avg         LogisticRegression       0.82    0.91      0.86  56962.0
# weighted avg      LogisticRegression       1.00    1.00      1.00  56962.0
# 0               KNeighborsClassifier       1.00    1.00      1.00  56880.0
# 1               KNeighborsClassifier       0.76    0.90      0.82     82.0
# accuracy        KNeighborsClassifier       1.00    1.00      1.00      1.0
# macro avg       KNeighborsClassifier       0.88    0.95      0.91  56962.0
# weighted avg    KNeighborsClassifier       1.00    1.00      1.00  56962.0
# 0                                SVC       1.00    1.00      1.00  56860.0
# 1                                SVC       0.82    0.78      0.80    102.0
# accuracy                         SVC       1.00    1.00      1.00      1.0
# macro avg                        SVC       0.91    0.89      0.90  56962.0
# weighted avg                     SVC       1.00    1.00      1.00  56962.0
# 0             DecisionTreeClassifier       1.00    1.00      1.00  56871.0
# 1             DecisionTreeClassifier       0.79    0.85      0.81     91.0
# accuracy      DecisionTreeClassifier       1.00    1.00      1.00      1.0
# macro avg     DecisionTreeClassifier       0.89    0.92      0.91  56962.0
# weighted avg  DecisionTreeClassifier       1.00    1.00      1.00  56962.0
# 0             RandomForestClassifier       1.00    1.00      1.00  56876.0
# 1             RandomForestClassifier       0.83    0.94      0.88     86.0
# accuracy      RandomForestClassifier       1.00    1.00      1.00      1.0
# macro avg     RandomForestClassifier       0.91    0.97      0.94  56962.0
# weighted avg  RandomForestClassifier       1.00    1.00      1.00  56962.0
# 0                 AdaBoostClassifier       1.00    1.00      1.00  56868.0
# 1                 AdaBoostClassifier       0.81    0.84      0.82     94.0
# accuracy          AdaBoostClassifier       1.00    1.00      1.00      1.0
# macro avg         AdaBoostClassifier       0.90    0.92      0.91  56962.0
# weighted avg      AdaBoostClassifier       1.00    1.00      1.00  56962.0

# %%
cl_report_over_before_sampling_models_test = getModelsClassificationReport(X_test_scaled, y_test, over_before_sampling_models)
# Out:
# Model : LogisticRegression
# Best params : {'C': 1, 'l1_ratio': 0, 'max_iter': 100000, 'penalty': 'elasticnet', 'solver': 'saga'}
# Took 0.04357099533081055 seconds
#
# Model : KNeighborsClassifier
# Best params : {'n_neighbors': 11}
# Took 1.2660033702850342 seconds
#
# Model : SVC
# Best params : {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# Took 0.13577008247375488 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'max_depth': 4, 'max_leaf_nodes': 10, 'min_samples_leaf': 3}
# Took 0.042806386947631836 seconds
#
# Model : RandomForestClassifier
# Best params : {'max_depth': 20, 'n_estimators': 400}
# Took 1.1759538650512695 seconds
#
# Model : AdaBoostClassifier
# Best params : {'learning_rate': 0.1, 'n_estimators': 100}
# Took 0.6873652935028076 seconds

# %%
cl_report_over_before_sampling_models_test
# Out:
#                                Model  precision  recall  f1-score   support
# 0                 LogisticRegression       0.96    1.00      0.98  54496.00
# 1                 LogisticRegression       0.93    0.04      0.07   2466.00
# accuracy          LogisticRegression       0.96    0.96      0.96      0.96
# macro avg         LogisticRegression       0.94    0.52      0.52  56962.00
# weighted avg      LogisticRegression       0.96    0.96      0.94  56962.00
# 0               KNeighborsClassifier       0.99    1.00      0.99  56163.00
# 1               KNeighborsClassifier       0.89    0.11      0.19    799.00
# accuracy        KNeighborsClassifier       0.99    0.99      0.99      0.99
# macro avg       KNeighborsClassifier       0.94    0.55      0.59  56962.00
# weighted avg    KNeighborsClassifier       0.99    0.99      0.98  56962.00
# 0                                SVC       0.97    1.00      0.98  54953.00
# 1                                SVC       0.91    0.04      0.08   2009.00
# accuracy                         SVC       0.97    0.97      0.97      0.97
# macro avg                        SVC       0.94    0.52      0.53  56962.00
# weighted avg                     SVC       0.96    0.97      0.95  56962.00
# 0             DecisionTreeClassifier       0.92    1.00      0.96  52453.00
# 1             DecisionTreeClassifier       0.93    0.02      0.04   4509.00
# accuracy      DecisionTreeClassifier       0.92    0.92      0.92      0.92
# macro avg     DecisionTreeClassifier       0.93    0.51      0.50  56962.00
# weighted avg  DecisionTreeClassifier       0.92    0.92      0.89  56962.00
# 0             RandomForestClassifier       0.97    1.00      0.98  55093.00
# 1             RandomForestClassifier       0.94    0.05      0.09   1869.00
# accuracy      RandomForestClassifier       0.97    0.97      0.97      0.97
# macro avg     RandomForestClassifier       0.95    0.52      0.54  56962.00
# weighted avg  RandomForestClassifier       0.97    0.97      0.95  56962.00
# 0                 AdaBoostClassifier       0.97    1.00      0.98  55095.00
# 1                 AdaBoostClassifier       0.91    0.05      0.09   1867.00
# accuracy          AdaBoostClassifier       0.97    0.97      0.97      0.97
# macro avg         AdaBoostClassifier       0.94    0.52      0.54  56962.00
# weighted avg      AdaBoostClassifier       0.97    0.97      0.95  56962.00

# %%
cl_report_smote_during_cv_models_test = getModelsClassificationReport(X_test_scaled, y_test, smote_during_cv_models)
# Out:
# Model : LogisticRegression
# Best params : {'classification__C': 0.01, 'classification__l1_ratio': 0.9, 'classification__max_iter': 100000, 'classification__penalty': 'elasticnet', 'classification__solver': 'saga'}
# Took 0.03529477119445801 seconds
#
# Model : KNeighborsClassifier
# Best params : {'classification__n_neighbors': 1}
# Took 14.284234285354614 seconds
#
# Model : SVC
# Best params : {'classification__C': 0.001, 'classification__kernel': 'rbf'}
# Took 316.1731767654419 seconds
#
# Model : DecisionTreeClassifier
# Best params : {'classification__max_depth': 2, 'classification__max_leaf_nodes': 20, 'classification__min_samples_leaf': 2}
# Took 0.03468751907348633 seconds
#
# Model : RandomForestClassifier
# Best params : {'classification__max_depth': 100, 'classification__n_estimators': 300}
# Took 1.2686433792114258 seconds
#
# Model : AdaBoostClassifier
# Best params : {'classification__learning_rate': 0.5, 'classification__n_estimators': 400}
# Took 2.4928765296936035 seconds

# %%
cl_report_smote_during_cv_models_test
# Out:
#                                Model  precision  recall  f1-score   support
# 0                 LogisticRegression       0.97    1.00      0.99  55412.00
# 1                 LogisticRegression       0.92    0.06      0.11   1550.00
# accuracy          LogisticRegression       0.97    0.97      0.97      0.97
# macro avg         LogisticRegression       0.95    0.53      0.55  56962.00
# weighted avg      LogisticRegression       0.97    0.97      0.96  56962.00
# 0               KNeighborsClassifier       1.00    1.00      1.00  56838.00
# 1               KNeighborsClassifier       0.85    0.67      0.75    124.00
# accuracy        KNeighborsClassifier       1.00    1.00      1.00      1.00
# macro avg       KNeighborsClassifier       0.92    0.83      0.87  56962.00
# weighted avg    KNeighborsClassifier       1.00    1.00      1.00  56962.00
# 0                                SVC       0.99    1.00      0.99  56112.00
# 1                                SVC       0.89    0.10      0.18    850.00
# accuracy                         SVC       0.99    0.99      0.99      0.99
# macro avg                        SVC       0.94    0.55      0.59  56962.00
# weighted avg                     SVC       0.99    0.99      0.98  56962.00
# 0             DecisionTreeClassifier       0.98    1.00      0.99  55728.00
# 1             DecisionTreeClassifier       0.87    0.07      0.13   1234.00
# accuracy      DecisionTreeClassifier       0.98    0.98      0.98      0.98
# macro avg     DecisionTreeClassifier       0.92    0.53      0.56  56962.00
# weighted avg  DecisionTreeClassifier       0.98    0.98      0.97  56962.00
# 0             RandomForestClassifier       1.00    1.00      1.00  56868.00
# 1             RandomForestClassifier       0.82    0.85      0.83     94.00
# accuracy      RandomForestClassifier       1.00    1.00      1.00      1.00
# macro avg     RandomForestClassifier       0.91    0.93      0.92  56962.00
# weighted avg  RandomForestClassifier       1.00    1.00      1.00  56962.00
# 0                 AdaBoostClassifier       0.99    1.00      0.99  56192.00
# 1                 AdaBoostClassifier       0.88    0.11      0.20    770.00
# accuracy          AdaBoostClassifier       0.99    0.99      0.99      0.99
# macro avg         AdaBoostClassifier       0.93    0.56      0.60  56962.00
# weighted avg      AdaBoostClassifier       0.99    0.99      0.98  56962.00

# %% [markdown]
# # Interpreting The Results

# %%
def getTrainTestDataFrame(train, test):
    new_train = train.copy()
    new_test = test.copy()

    new_train["Model"] = train["Model"].apply({lambda x: x + "_train"})
    new_test["Model"] = test["Model"].apply({lambda x: x + "_test"})
    
    return pd.concat([new_train, new_test], axis=1)

# %%
getTrainTestDataFrame (cl_report_under_sample_models_train, cl_report_under_sample_models_test).loc[["1", "macro avg", "weighted avg"]]
# Out:
#                                      Model  precision  recall  f1-score  \
# 1                 LogisticRegression_train       0.93    0.95      0.94
# 1               KNeighborsClassifier_train       0.89    0.98      0.93
# 1                                SVC_train       0.93    0.96      0.94
# 1             DecisionTreeClassifier_train       0.94    0.95      0.94
# 1             RandomForestClassifier_train       1.00    0.97      0.99
# 1                 AdaBoostClassifier_train       0.90    0.97      0.93
# macro avg         LogisticRegression_train       0.94    0.94      0.94
# macro avg       KNeighborsClassifier_train       0.93    0.94      0.93
# macro avg                        SVC_train       0.94    0.94      0.94
# macro avg     DecisionTreeClassifier_train       0.94    0.94      0.94
# macro avg     RandomForestClassifier_train       0.99    0.99      0.99
# macro avg         AdaBoostClassifier_train       0.94    0.94      0.94
# weighted avg      LogisticRegression_train       0.94    0.94      0.94
# weighted avg    KNeighborsClassifier_train       0.94    0.93      0.93
# weighted avg                     SVC_train       0.94    0.94      0.94
# weighted avg  DecisionTreeClassifier_train       0.94    0.94      0.94
# weighted avg  RandomForestClassifier_train       0.99    0.99      0.99
# weighted avg      AdaBoostClassifier_train       0.94    0.94      0.94
#
#               support                        Model  precision  recall  \
# 1               386.0      LogisticRegression_test       0.92    0.04
# 1               358.0    KNeighborsClassifier_test       0.89    0.10
# 1               380.0                     SVC_test       0.91    0.05
# 1               390.0  DecisionTreeClassifier_test       0.89    0.03
# 1               405.0  RandomForestClassifier_test       0.91    0.05
# 1               367.0      AdaBoostClassifier_test       0.90    0.06
# macro avg       788.0      LogisticRegression_test       0.94    0.52
# macro avg       788.0    KNeighborsClassifier_test       0.94    0.55
# macro avg       788.0                     SVC_test       0.94    0.52
# macro avg       788.0  DecisionTreeClassifier_test       0.92    0.51
# macro avg       788.0  RandomForestClassifier_test       0.94    0.52
# macro avg       788.0      AdaBoostClassifier_test       0.94    0.53
# weighted avg    788.0      LogisticRegression_test       0.96    0.96
# weighted avg    788.0    KNeighborsClassifier_test       0.98    0.99
# weighted avg    788.0                     SVC_test       0.97    0.97
# weighted avg    788.0  DecisionTreeClassifier_test       0.95    0.95
# weighted avg    788.0  RandomForestClassifier_test       0.97    0.97
# weighted avg    788.0      AdaBoostClassifier_test       0.97    0.97
#
#               f1-score  support
# 1                 0.08   2214.0
# 1                 0.18    893.0
# 1                 0.09   1880.0
# 1                 0.06   2881.0
# 1                 0.09   1902.0
# 1                 0.11   1506.0
# macro avg         0.53  56962.0
# macro avg         0.58  56962.0
# macro avg         0.54  56962.0
# macro avg         0.52  56962.0
# macro avg         0.54  56962.0
# macro avg         0.55  56962.0
# weighted avg      0.95  56962.0
# weighted avg      0.98  56962.0
# weighted avg      0.95  56962.0
# weighted avg      0.93  56962.0
# weighted avg      0.95  56962.0
# weighted avg      0.96  56962.0

# %% [markdown]
# Despite the fact that we undersampled the data so that the classes are balanced all of our models didn't generalized well. It seems that they are overfitting the data. But that doesn't explain why our models are biased towards the negative class they seem to only be guessing negative. That could some noise in the data coming from the PCA done beforehand.

# %%
getTrainTestDataFrame(cl_report_under_sample_models_nm_train, cl_report_under_sample_models_nm_test).loc[["1", "macro avg", "weighted avg"]]
# Out:
#                                      Model  precision  recall  f1-score  \
# 1                 LogisticRegression_train       0.91    0.99      0.95
# 1               KNeighborsClassifier_train       0.89    0.99      0.94
# 1                                SVC_train       0.93    0.99      0.96
# 1             DecisionTreeClassifier_train       0.95    1.00      0.97
# 1             RandomForestClassifier_train       1.00    1.00      1.00
# 1                 AdaBoostClassifier_train       1.00    1.00      1.00
# macro avg         LogisticRegression_train       0.95    0.95      0.95
# macro avg       KNeighborsClassifier_train       0.94    0.94      0.94
# macro avg                        SVC_train       0.96    0.96      0.96
# macro avg     DecisionTreeClassifier_train       0.97    0.97      0.97
# macro avg     RandomForestClassifier_train       1.00    1.00      1.00
# macro avg         AdaBoostClassifier_train       1.00    1.00      1.00
# weighted avg      LogisticRegression_train       0.95    0.95      0.95
# weighted avg    KNeighborsClassifier_train       0.94    0.94      0.94
# weighted avg                     SVC_train       0.96    0.96      0.96
# weighted avg  DecisionTreeClassifier_train       0.97    0.97      0.97
# weighted avg  RandomForestClassifier_train       1.00    1.00      1.00
# weighted avg      AdaBoostClassifier_train       1.00    1.00      1.00
#
#               support                        Model  precision  recall  \
# 1               365.0      LogisticRegression_test       0.92    0.06
# 1               356.0    KNeighborsClassifier_test       0.91    0.10
# 1               368.0                     SVC_test       0.92    0.04
# 1               373.0  DecisionTreeClassifier_test       0.91    0.01
# 1               394.0  RandomForestClassifier_test       0.95    0.01
# 1               394.0      AdaBoostClassifier_test       0.96    0.01
# macro avg       788.0      LogisticRegression_test       0.95    0.53
# macro avg       788.0    KNeighborsClassifier_test       0.95    0.55
# macro avg       788.0                     SVC_test       0.94    0.52
# macro avg       788.0  DecisionTreeClassifier_test       0.82    0.50
# macro avg       788.0  RandomForestClassifier_test       0.84    0.50
# macro avg       788.0      AdaBoostClassifier_test       0.83    0.50
# weighted avg    788.0      LogisticRegression_test       0.97    0.97
# weighted avg    788.0    KNeighborsClassifier_test       0.98    0.99
# weighted avg    788.0                     SVC_test       0.96    0.96
# weighted avg    788.0  DecisionTreeClassifier_test       0.78    0.73
# weighted avg    788.0  RandomForestClassifier_test       0.79    0.73
# weighted avg    788.0      AdaBoostClassifier_test       0.77    0.69
#
#               f1-score  support
# 1                 0.11   1613.0
# 1                 0.18    886.0
# 1                 0.07   2456.0
# 1                 0.01  15669.0
# 1                 0.01  15629.0
# 1                 0.01  17589.0
# macro avg         0.55  56962.0
# macro avg         0.59  56962.0
# macro avg         0.52  56962.0
# macro avg         0.43  56962.0
# macro avg         0.43  56962.0
# macro avg         0.41  56962.0
# weighted avg      0.96  56962.0
# weighted avg      0.98  56962.0
# weighted avg      0.94  56962.0
# weighted avg      0.61  56962.0
# weighted avg      0.61  56962.0
# weighted avg      0.57  56962.0

# %% [markdown]
# With Near Miss we see pretty much the same results.

# %%
getTrainTestDataFrame (cl_report_under_sample_models_pca_train, cl_report_under_sample_models_pca_test).loc[["1", "macro avg", "weighted avg"]]
# Out:
#                                      Model  precision  recall  f1-score  \
# 1                 LogisticRegression_train       0.87    0.97      0.92
# 1               KNeighborsClassifier_train       0.89    0.97      0.93
# 1                                SVC_train       0.86    0.98      0.92
# 1             DecisionTreeClassifier_train       0.90    0.95      0.92
# 1             RandomForestClassifier_train       0.94    0.95      0.94
# 1                 AdaBoostClassifier_train       0.90    0.96      0.93
# macro avg         LogisticRegression_train       0.92    0.93      0.92
# macro avg       KNeighborsClassifier_train       0.93    0.94      0.93
# macro avg                        SVC_train       0.92    0.93      0.92
# macro avg     DecisionTreeClassifier_train       0.93    0.93      0.93
# macro avg     RandomForestClassifier_train       0.94    0.94      0.94
# macro avg         AdaBoostClassifier_train       0.93    0.93      0.93
# weighted avg      LogisticRegression_train       0.93    0.92      0.92
# weighted avg    KNeighborsClassifier_train       0.94    0.93      0.93
# weighted avg                     SVC_train       0.93    0.92      0.92
# weighted avg  DecisionTreeClassifier_train       0.93    0.93      0.93
# weighted avg  RandomForestClassifier_train       0.94    0.94      0.94
# weighted avg      AdaBoostClassifier_train       0.93    0.93      0.93
#
#               support                        Model  precision  recall  \
# 1               351.0      LogisticRegression_test       0.89    0.09
# 1               363.0    KNeighborsClassifier_test       0.90    0.06
# 1               348.0                     SVC_test       0.89    0.11
# 1               374.0  DecisionTreeClassifier_test       0.90    0.03
# 1               388.0  RandomForestClassifier_test       0.92    0.04
# 1               371.0      AdaBoostClassifier_test       0.91    0.05
# macro avg       788.0      LogisticRegression_test       0.94    0.55
# macro avg       788.0    KNeighborsClassifier_test       0.94    0.53
# macro avg       788.0                     SVC_test       0.94    0.55
# macro avg       788.0  DecisionTreeClassifier_test       0.93    0.52
# macro avg       788.0  RandomForestClassifier_test       0.94    0.52
# macro avg       788.0      AdaBoostClassifier_test       0.94    0.53
# weighted avg    788.0      LogisticRegression_test       0.98    0.98
# weighted avg    788.0    KNeighborsClassifier_test       0.97    0.98
# weighted avg    788.0                     SVC_test       0.99    0.99
# weighted avg    788.0  DecisionTreeClassifier_test       0.95    0.95
# weighted avg    788.0  RandomForestClassifier_test       0.96    0.96
# weighted avg    788.0      AdaBoostClassifier_test       0.97    0.97
#
#               f1-score  support
# 1                 0.16    958.0
# 1                 0.12   1406.0
# 1                 0.19    799.0
# 1                 0.06   2786.0
# 1                 0.07   2396.0
# 1                 0.10   1729.0
# macro avg         0.58  56962.0
# macro avg         0.55  56962.0
# macro avg         0.59  56962.0
# macro avg         0.52  56962.0
# macro avg         0.53  56962.0
# macro avg         0.54  56962.0
# weighted avg      0.98  56962.0
# weighted avg      0.97  56962.0
# weighted avg      0.98  56962.0
# weighted avg      0.93  56962.0
# weighted avg      0.94  56962.0
# weighted avg      0.96  56962.0

# %% [markdown]
# With PCA we get slightly worse results for the training but better for the testing it seems that the our models are overfitting.

# %%
getTrainTestDataFrame (cl_report_no_sampling_models_train, cl_report_no_sampling_models_test).loc[["1", "macro avg", "weighted avg"]]
# Out:
#                                      Model  precision  recall  f1-score  \
# 1                 LogisticRegression_train       0.64    0.89      0.74
# 1               KNeighborsClassifier_train       0.76    0.91      0.83
# 1                                SVC_train       0.79    0.85      0.82
# 1             DecisionTreeClassifier_train       0.79    0.90      0.84
# 1             RandomForestClassifier_train       1.00    1.00      1.00
# 1                 AdaBoostClassifier_train       0.80    0.95      0.87
# macro avg         LogisticRegression_train       0.82    0.94      0.87
# macro avg       KNeighborsClassifier_train       0.88    0.96      0.92
# macro avg                        SVC_train       0.90    0.93      0.91
# macro avg     DecisionTreeClassifier_train       0.90    0.95      0.92
# macro avg     RandomForestClassifier_train       1.00    1.00      1.00
# macro avg         AdaBoostClassifier_train       0.90    0.97      0.93
# weighted avg      LogisticRegression_train       1.00    1.00      1.00
# weighted avg    KNeighborsClassifier_train       1.00    1.00      1.00
# weighted avg                     SVC_train       1.00    1.00      1.00
# weighted avg  DecisionTreeClassifier_train       1.00    1.00      1.00
# weighted avg  RandomForestClassifier_train       1.00    1.00      1.00
# weighted avg      AdaBoostClassifier_train       1.00    1.00      1.00
#
#                support                        Model  precision  recall  \
# 1                282.0      LogisticRegression_test       0.64    0.83
# 1                328.0    KNeighborsClassifier_test       0.76    0.90
# 1                366.0                     SVC_test       0.82    0.78
# 1                347.0  DecisionTreeClassifier_test       0.79    0.85
# 1                394.0  RandomForestClassifier_test       0.83    0.94
# 1                333.0      AdaBoostClassifier_test       0.81    0.84
# macro avg     227845.0      LogisticRegression_test       0.82    0.91
# macro avg     227845.0    KNeighborsClassifier_test       0.88    0.95
# macro avg     227845.0                     SVC_test       0.91    0.89
# macro avg     227845.0  DecisionTreeClassifier_test       0.89    0.92
# macro avg     227845.0  RandomForestClassifier_test       0.91    0.97
# macro avg     227845.0      AdaBoostClassifier_test       0.90    0.92
# weighted avg  227845.0      LogisticRegression_test       1.00    1.00
# weighted avg  227845.0    KNeighborsClassifier_test       1.00    1.00
# weighted avg  227845.0                     SVC_test       1.00    1.00
# weighted avg  227845.0  DecisionTreeClassifier_test       1.00    1.00
# weighted avg  227845.0  RandomForestClassifier_test       1.00    1.00
# weighted avg  227845.0      AdaBoostClassifier_test       1.00    1.00
#
#               f1-score  support
# 1                 0.72     76.0
# 1                 0.82     82.0
# 1                 0.80    102.0
# 1                 0.81     91.0
# 1                 0.88     86.0
# 1                 0.82     94.0
# macro avg         0.86  56962.0
# macro avg         0.91  56962.0
# macro avg         0.90  56962.0
# macro avg         0.91  56962.0
# macro avg         0.94  56962.0
# macro avg         0.91  56962.0
# weighted avg      1.00  56962.0
# weighted avg      1.00  56962.0
# weighted avg      1.00  56962.0
# weighted avg      1.00  56962.0
# weighted avg      1.00  56962.0
# weighted avg      1.00  56962.0

# %% [markdown]
# Without any sampling we get our best results yet the models also generalize well only the random forest classifier seems to be very slightly overfitting to the negative class.

# %%
getTrainTestDataFrame(cl_report_over_before_sampling_models_train, cl_report_over_before_sampling_models_test).loc[["1", "macro avg", "weighted avg"]]
# Out:
#                                      Model  precision  recall  f1-score  \
# 1                 LogisticRegression_train       0.98    0.96      0.97
# 1               KNeighborsClassifier_train       0.91    0.99      0.95
# 1                                SVC_train       0.97    0.97      0.97
# 1             DecisionTreeClassifier_train       0.95    0.93      0.94
# 1             RandomForestClassifier_train       0.97    0.97      0.97
# 1                 AdaBoostClassifier_train       0.96    0.97      0.96
# macro avg         LogisticRegression_train       0.97    0.97      0.97
# macro avg       KNeighborsClassifier_train       0.95    0.95      0.95
# macro avg                        SVC_train       0.97    0.97      0.97
# macro avg     DecisionTreeClassifier_train       0.94    0.94      0.94
# macro avg     RandomForestClassifier_train       0.97    0.97      0.97
# macro avg         AdaBoostClassifier_train       0.96    0.96      0.96
# weighted avg      LogisticRegression_train       0.97    0.97      0.97
# weighted avg    KNeighborsClassifier_train       0.95    0.95      0.95
# weighted avg                     SVC_train       0.97    0.97      0.97
# weighted avg  DecisionTreeClassifier_train       0.94    0.94      0.94
# weighted avg  RandomForestClassifier_train       0.97    0.97      0.97
# weighted avg      AdaBoostClassifier_train       0.96    0.96      0.96
#
#                support                        Model  precision  recall  \
# 1             231243.0      LogisticRegression_test       0.93    0.04
# 1             210397.0    KNeighborsClassifier_test       0.89    0.11
# 1             227392.0                     SVC_test       0.91    0.04
# 1             233941.0  DecisionTreeClassifier_test       0.93    0.02
# 1             227996.0  RandomForestClassifier_test       0.94    0.05
# 1             224216.0      AdaBoostClassifier_test       0.91    0.05
# macro avg     454902.0      LogisticRegression_test       0.94    0.52
# macro avg     454902.0    KNeighborsClassifier_test       0.94    0.55
# macro avg     454902.0                     SVC_test       0.94    0.52
# macro avg     454902.0  DecisionTreeClassifier_test       0.93    0.51
# macro avg     454902.0  RandomForestClassifier_test       0.95    0.52
# macro avg     454902.0      AdaBoostClassifier_test       0.94    0.52
# weighted avg  454902.0      LogisticRegression_test       0.96    0.96
# weighted avg  454902.0    KNeighborsClassifier_test       0.99    0.99
# weighted avg  454902.0                     SVC_test       0.96    0.97
# weighted avg  454902.0  DecisionTreeClassifier_test       0.92    0.92
# weighted avg  454902.0  RandomForestClassifier_test       0.97    0.97
# weighted avg  454902.0      AdaBoostClassifier_test       0.97    0.97
#
#               f1-score  support
# 1                 0.07   2466.0
# 1                 0.19    799.0
# 1                 0.08   2009.0
# 1                 0.04   4509.0
# 1                 0.09   1869.0
# 1                 0.09   1867.0
# macro avg         0.52  56962.0
# macro avg         0.59  56962.0
# macro avg         0.53  56962.0
# macro avg         0.50  56962.0
# macro avg         0.54  56962.0
# macro avg         0.54  56962.0
# weighted avg      0.94  56962.0
# weighted avg      0.98  56962.0
# weighted avg      0.95  56962.0
# weighted avg      0.89  56962.0
# weighted avg      0.95  56962.0
# weighted avg      0.95  56962.0

# %% [markdown]
# As expected with oversampling before the cross-validation we got extreme overfitting and our worst result yet.

# %%
getTrainTestDataFrame(cl_report_smote_during_cv_models_train, cl_report_smote_during_cv_models_test).loc[["1", "macro avg", "weighted avg"]]
# Out:
#                                      Model  precision  recall  f1-score  \
# 1                 LogisticRegression_train       0.93    0.06      0.11
# 1               KNeighborsClassifier_train       1.00    1.00      1.00
# 1                                SVC_train       0.88    0.11      0.19
# 1             DecisionTreeClassifier_train       0.86    0.07      0.13
# 1             RandomForestClassifier_train       1.00    1.00      1.00
# 1                 AdaBoostClassifier_train       0.97    0.13      0.23
# macro avg         LogisticRegression_train       0.95    0.53      0.55
# macro avg       KNeighborsClassifier_train       1.00    1.00      1.00
# macro avg                        SVC_train       0.93    0.55      0.59
# macro avg     DecisionTreeClassifier_train       0.92    0.54      0.56
# macro avg     RandomForestClassifier_train       1.00    1.00      1.00
# macro avg         AdaBoostClassifier_train       0.98    0.56      0.61
# weighted avg      LogisticRegression_train       0.97    0.97      0.96
# weighted avg    KNeighborsClassifier_train       1.00    1.00      1.00
# weighted avg                     SVC_train       0.99    0.99      0.98
# weighted avg  DecisionTreeClassifier_train       0.98    0.98      0.97
# weighted avg  RandomForestClassifier_train       1.00    1.00      1.00
# weighted avg      AdaBoostClassifier_train       0.99    0.99      0.98
#
#                support                        Model  precision  recall  \
# 1               6176.0      LogisticRegression_test       0.92    0.06
# 1                394.0    KNeighborsClassifier_test       0.85    0.67
# 1               3253.0                     SVC_test       0.89    0.10
# 1               4733.0  DecisionTreeClassifier_test       0.87    0.07
# 1                394.0  RandomForestClassifier_test       0.82    0.85
# 1               2989.0      AdaBoostClassifier_test       0.88    0.11
# macro avg     227845.0      LogisticRegression_test       0.95    0.53
# macro avg     227845.0    KNeighborsClassifier_test       0.92    0.83
# macro avg     227845.0                     SVC_test       0.94    0.55
# macro avg     227845.0  DecisionTreeClassifier_test       0.92    0.53
# macro avg     227845.0  RandomForestClassifier_test       0.91    0.93
# macro avg     227845.0      AdaBoostClassifier_test       0.93    0.56
# weighted avg  227845.0      LogisticRegression_test       0.97    0.97
# weighted avg  227845.0    KNeighborsClassifier_test       1.00    1.00
# weighted avg  227845.0                     SVC_test       0.99    0.99
# weighted avg  227845.0  DecisionTreeClassifier_test       0.98    0.98
# weighted avg  227845.0  RandomForestClassifier_test       1.00    1.00
# weighted avg  227845.0      AdaBoostClassifier_test       0.99    0.99
#
#               f1-score  support
# 1                 0.11   1550.0
# 1                 0.75    124.0
# 1                 0.18    850.0
# 1                 0.13   1234.0
# 1                 0.83     94.0
# 1                 0.20    770.0
# macro avg         0.55  56962.0
# macro avg         0.87  56962.0
# macro avg         0.59  56962.0
# macro avg         0.56  56962.0
# macro avg         0.92  56962.0
# macro avg         0.60  56962.0
# weighted avg      0.96  56962.0
# weighted avg      1.00  56962.0
# weighted avg      0.98  56962.0
# weighted avg      0.97  56962.0
# weighted avg      1.00  56962.0
# weighted avg      0.98  56962.0

# %% [markdown]
# When doing the oversampling during the cross-validation process we don't see the extreme overfitting we saw when we did it before the cross-validation. Not only that it seems that a lot of our models are not complex enough to be able to fit to the data(i.e. have high bias) the random forest classifier got good results but they are still worse than the ones we got when we didn't do no sampling and just used f1 scoring and stratified k-fold cross-validation.

# %% [markdown]
# # Discussion On Limitations/Issues With Methodologies And Potential Expansions/Fixes

# %% [markdown]
# There are a lot of different ways to expand on these results. First, we could have tried do "n-1" folds cross validation on the undersampled data with more hyper parameter tuning and higher regularization to see if that would have helped with the overfitting. Second, we could have done cross tried more folds for the oversampled during cross validation data with more complex models and maybe even neural networks to see what the results would have. Our data could have been more processed despite the fact that our attributes were the results of a PCA analysis we could still have done more EDA to check for outliers we saw that our Amounts attribute was very imbalanced maybe removing some of the outliers or using a scaler that could would reduce their effect like the RobustScaler. The way we scored our models is also arguable because we might care more about the precision since the transactions are generally very small. A company would maybe rather take the cost of refunding customers which have been scammed rather than flagging a lot non fraudulent transactions as fraudulent and potentially losing customers due to dissatisfaction with the service. Or maybe even crating two different models one with high precision and another with high recall. Using the using the first to score transactions with small amounts and the second to score transactions with large amounts.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Using different sampling methods didn't give use meaningful improvement in performance for unbalanced data with regards to f1 score.Compared to when using stratified cross validation. But still these techniques might be useful if we want to create a more complex model or if we don't have the resources required to train the models using all of the data.

# %%
#final_model = RandomForestClassifier( max_depth = 100, n_estimators = 100)

# %%
#final_model.fit(scaler.transform(attributes), labels)
# Out:
# RandomForestClassifier(max_depth=100)

# %%
#pickleModels([final_model], "final_model")

# %%
final_model = unPickleModels("final_model")[0]

# %% [markdown]
# # Resources

# %% [markdown]
# https://www.kaggle.com/datasets/whenamancodes/fraud-detection/code?datasetId=2472961&sortBy=voteCount
#
# https://imbalanced-learn.org/stable/references/generated/imblearn.under_sampling.NearMiss.html
#
# https://www.analyticsvidhya.com/blog/2020/07/10-techniques-to-deal-with-class-imbalance-in-machine-learning/?
#
# https://medium.com/@corymaklin/synthetic-minority-over-sampling-technique-smote-7d419696b88c
#
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/
#
# https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SMOTE.html
#
# https://machinelearningmastery.com/random-oversampling-and-undersampling-for-imbalanced-classification/
#
# https://www.marcoaltini.com/blog/dealing-with-imbalanced-data-undersampling-oversampling-and-proper-cross-validation
#
# https://rikunert.com/SMOTE_explained
